# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/1900_2021_DISASTERS.xlsx - emdat data.csv')

#POZNANIE DANYCH
print (df.head())
#print(df.info())
#print(df.describe())
#print(df["Disaster Type"].value_counts())
#print(df["Disaster Group"].value_counts())
# Out:
#    Year   Seq Glide Disaster Group Disaster Subgroup      Disaster Type  \
# 0  1900  9002   NaN        Natural    Climatological            Drought
# 1  1900  9001   NaN        Natural    Climatological            Drought
# 2  1902    12   NaN        Natural       Geophysical         Earthquake
# 3  1902     3   NaN        Natural       Geophysical  Volcanic activity
# 4  1902    10   NaN        Natural       Geophysical  Volcanic activity
#
#   Disaster Subtype Disaster Subsubtype   Event Name     Country  ...  \
# 0          Drought                 NaN          NaN  Cabo Verde  ...
# 1          Drought                 NaN          NaN       India  ...
# 2  Ground movement                 NaN          NaN   Guatemala  ...
# 3         Ash fall                 NaN  Santa Maria   Guatemala  ...
# 4         Ash fall                 NaN  Santa Maria   Guatemala  ...
#
#   No Affected No Homeless Total Affected Insured Damages ('000 US$)  \
# ...

# %%
#df[['Year', 'Disaster Type','Start Year', 'End Year']]
df[df['Start Year'] != df['End Year']][['Year', 'Disaster Type','Start Year', 'End Year', 'Origin']].sort_values(by=['Year', 'Disaster Type','Start Year', 'End Year', 'Origin'])
# Out:
#        Year       Disaster Type  Start Year  End Year  \
# 864    1906             Drought        1906      1907
# 24     1910             Drought        1910      1914
# 27     1910             Drought        1910      1914
# 30     1910             Drought        1910      1914
# 31     1910             Drought        1910      1914
# ...     ...                 ...         ...       ...
# 15061  2019  Insect infestation        2019      2020
# 15471  2019  Insect infestation        2019      2020
# 15026  2019            Wildfire        2019      2020
# 15628  2020             Drought        2020      2021
# 16051  2020            Epidemic        2020      2021
#
#                                      Origin
# 864                                     NaN
# 24                                      NaN
# 27                                      NaN
# 30                                      NaN
# 31                                      NaN
# ...                                     ...
# ...

# %%
df[df['Start Year'] != df['Year']][['Year', 'Disaster Type','Start Year', 'End Year', 'Origin']].sort_values(by=['Year', 'Disaster Type','Start Year', 'End Year', 'Origin'])
#uzywajmy "start year" zamiast "year"
# Out:
#        Year       Disaster Type  Start Year  End Year      Origin
# 859    1905          Earthquake        1907      1907  Earthquake
# 15328  1914          Earthquake        1930      1930         NaN
# 14795  1941          Earthquake        1931      1931         NaN
# 15411  1965          Earthquake        2020      2020         NaN
# 486    1969             Drought        1971      1975         NaN
# ...     ...                 ...         ...       ...         ...
# 15470  2019  Insect infestation        2020      2020         NaN
# 15551  2019  Insect infestation        2020      2020         NaN
# 15986  2019  Insect infestation        2020      2020         NaN
# 15678  2020               Storm        2021      2021         NaN
# 15703  2020               Storm        2021      2021         NaN
#
# [130 rows x 5 columns]

# %%
for col in df.columns:
   print(col) 
   print((df[col]).unique())
   print ("***")

#zweryfikować czy są wszystkie lata - groupby by year
# Out:
# Year
# [1900 1902 1903 1904 1905 1906 1907 1908 1909 1910 1911 1912 1914 1915
#  1916 1917 1918 1919 1920 1921 1922 1923 1924 1925 1926 1927 1928 1929
#  1930 1931 1932 1933 1934 1935 1936 1937 1938 1939 1940 1941 1942 1943
#  1944 1945 1946 1947 1948 1949 1950 1951 1952 1953 1954 1955 1956 1957
#  1958 1959 1960 1961 1962 1963 1964 1965 1966 1967 1968 1969 1970 1971
#  1972 1973 1974 1975 1976 1977 1978 1901 1913 1979 1980 1981 1982 1983
#  1984 1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996 1997
#  1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011
#  2012 2013 2014 2015 2016 2017 2018 2019 2020 2021]
# ***
# Seq
# [9002 9001   12 ... 9667 9598 9639]
# ***
# Glide
# [nan 'FL-2007-000040' 'FL-2007-000022' ... 'VO-2021-000034'
#  'FL-2021-000110' 'EP-2021-000138']
# ***
# Disaster Group
# ['Natural']
# ***
# Disaster Subgroup
# ['Climatological' 'Geophysical' 'Meteorological' 'Hydrological'
#  'Biological' 'Extra-terrestrial']
# ***
# Disaster Type
# ...

# %%
print (df.columns)
# Out:
# Index(['Year', 'Seq', 'Glide', 'Disaster Group', 'Disaster Subgroup',
#        'Disaster Type', 'Disaster Subtype', 'Disaster Subsubtype',
#        'Event Name', 'Country', 'ISO', 'Region', 'Continent', 'Location',
#        'Origin', 'Associated Dis', 'Associated Dis2', 'OFDA Response',
#        'Appeal', 'Declaration', 'Aid Contribution', 'Dis Mag Value',
#        'Dis Mag Scale', 'Latitude', 'Longitude', 'Local Time', 'River Basin',
#        'Start Year', 'Start Month', 'Start Day', 'End Year', 'End Month',
#        'End Day', 'Total Deaths', 'No Injured', 'No Affected', 'No Homeless',
#        'Total Affected', 'Insured Damages ('000 US$)',
#        'Total Damages ('000 US$)', 'CPI', 'Adm Level', 'Admin1 Code',
#        'Admin2 Code', 'Geo Locations'],
#       dtype='object')

# %% [markdown]
# Do wyrzucenia:
# throw_out = ["Seq", "Glide","Disaster Group", "Disaster Subsubtype", "Event Name", "Location", "Origin", "Associated Dis", "Associated Dis2", "OFDA Response", "Appeal", "Declaration", "Aid Contribution", 'Dis Mag Value', 'Dis Mag Scale', 'Latitude', 'Longitude', 'Local Time', 'River Basin','Start Month', 'Start Day','Start Day', 'End Year', 'End Month','End Day', 'No Injured', 'No Affected', 'No Homeless','Total Affected', 'Insured Damages ('000 US$)','Total Damages ('000 US$)', 'CPI', 'Adm Level', 'Admin1 Code','Admin2 Code', 'Geo Locations']

# %%
final_df = df.drop(["Year","Seq", "Glide","Disaster Group", "Disaster Subsubtype", "Event Name", "Location", "Origin", "Associated Dis", "Associated Dis2", "OFDA Response", "Appeal", "Declaration", "Aid Contribution", 'Dis Mag Value', 'Dis Mag Scale', 'Latitude', 'Longitude', 'Local Time', 'River Basin','Start Month', 'Start Day','Start Day', 'End Year', 'End Month','End Day', 'No Injured', 'No Affected', 'No Homeless','Total Affected', "Insured Damages ('000 US$)","Total Damages ('000 US$)", 'CPI', 'Adm Level', 'Admin1 Code','Admin2 Code', 'Geo Locations'], axis=1)

final_df.head()
# Out:
#   Disaster Subgroup      Disaster Type Disaster Subtype     Country  ISO  \
# 0    Climatological            Drought          Drought  Cabo Verde  CPV
# 1    Climatological            Drought          Drought       India  IND
# 2       Geophysical         Earthquake  Ground movement   Guatemala  GTM
# 3       Geophysical  Volcanic activity         Ash fall   Guatemala  GTM
# 4       Geophysical  Volcanic activity         Ash fall   Guatemala  GTM
#
#             Region Continent  Start Year  Total Deaths
# 0   Western Africa    Africa        1900       11000.0
# 1    Southern Asia      Asia        1900     1250000.0
# 2  Central America  Americas        1902        2000.0
# 3  Central America  Americas        1902        1000.0
# 4  Central America  Americas        1902        6000.0

# %%
#CZYSZCZENIE
print(final_df.isna().sum())
# Out:
# Disaster Subgroup       0
# Disaster Type           0
# Disaster Subtype     3110
# Country                 0
# ISO                     0
# Region                  0
# Continent               0
# Start Year              0
# Total Deaths         4713
# dtype: int64

# %%
#WIZUALIZACJA
disaster_type_countplot = sns.countplot(data=final_df, x = "Disaster Type", order=final_df['Disaster Type'].value_counts().index)
disaster_type_countplot.set_xticklabels(disaster_type_countplot.get_xticklabels(), rotation=40,ha="right")
plt.tight_layout()
plt.show()

sns.histplot(data=final_df, binwidth = 1, x = "Start Year")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17912\2980030980.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   disaster_type_countplot.set_xticklabels(disaster_type_countplot.get_xticklabels(), rotation=40,ha="right")

# %%
region_countplot = sns.countplot(data=final_df, x = "Region", order=final_df['Region'].value_counts().index)
region_countplot.set_xticklabels(region_countplot.get_xticklabels(), rotation=40,ha="right")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17912\1005280782.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   region_countplot.set_xticklabels(region_countplot.get_xticklabels(), rotation=40,ha="right")

# %%
scatter1 = sns.scatterplot(data=final_df, x = "Disaster Type", y = "Total Deaths")
scatter1.set_xticklabels(scatter1.get_xticklabels(), rotation=40,ha="right")
plt.tight_layout()
plt.show()

#podsumować liczbę śmierci (groupby; sum) dla konkretnych katastrof i zrobić barplot
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17912\2888456262.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   scatter1.set_xticklabels(scatter1.get_xticklabels(), rotation=40,ha="right")

# %%
#scatter2 = sns.scatterplot(data=final_df, x= "Start Year", y = "Disaster Type", hue="Continent")
#scatter2.set_xticklabels(scatter2.get_xticklabels(), rotation=40,ha="right")
#plt.tight_layout()
#plt.show()

# zrobić subplots dla każdego typu disaster (seaborn -> subplots). zrobić liniowy graf 
# (częstość występowania i każda linia = inny kontynent; ważne! linia powinna mieć kropki, 
# a nie ciągła linia - zeby pokazywać przerwy miedzy wydarzeniami)

#lineplot_y = final_df.groupby("Continent").count()
#lineplot = plt.plot("Start Year",lineplot_y, data=final_df, label ="Continent")
#lineplot.set_xticklabels(lineplot.get_xticklabels(), rotation=40,ha="right")
#plt.tight_layout()
#plt.show()

#grouped_df = final_df.groupby(['Start Year', 'Continent'])['Disaster Type'].sum().reset_index()

# Plot the lines for each continent
#plt.figure(figsize=(10, 6))
#for continent in final_df['Continent'].unique():
#    continent_data = grouped_df[grouped_df['Continent'] == continent]
#    plt.plot(continent_data['Start Year'], continent_data['Disaster Type'], label=continent)
# Set labels and title
#plt.xlabel('Year')
#plt.ylabel('Natural Disasters Count')
#plt.title('Natural Disasters Count Over Years by Continent')

# Show legend
#plt.legend()

# Show the plot
#plt.show()

#kde_continent = sns.kdeplot(data=final_df, x="Start Year",hue="Continent", cut=0)
#kde_continent.set_xticklabels(kde_continent.get_xticklabels(), rotation=40,ha="right")
#plt.tight_layout()
#plt.show()

#do linii dodać kropki
# zmienić kdplot na inną liniową metodę (lineplot w mtpl)
# wykres subplot na kontynetnty, a potem na regiony: https://stackoverflow.com/questions/73818599/subplots-with-time-series

# %%
#plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
#plt.plot(final_df['Start Year'], final_df['Continent'],linestyle='--', marker='o', color='gray')
#plt.plot(final_df['Start Year'],final_df[''], linestyle='--', marker='o')

# Set labels and title
#plt.xlabel('Year')
#plt.ylabel('Number of Events')
#plt.title('Number of Events Over Years')
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\Desktop\mentoring\DISASTERS\.venv\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[123], line 3
# ...

# %%
#line_sns = sns.lineplot(data = final_df, x = "Start Year", y = final_df["Disaster Type"].groupby("Continent").count(), hue="Continent")
#line_sns.set_xticklabels(line_sns.get_xticklabels(), rotation=40,ha="right")
plt.tight_layout()
plt.show()

# %%
final_df_grouped = final_df.groupby("Start Year").count()
final_df_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 122 entries, 1900 to 2021
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Disaster Subgroup  122 non-null    int64
#  1   Disaster Type      122 non-null    int64
#  2   Disaster Subtype   122 non-null    int64
#  3   Country            122 non-null    int64
#  4   ISO                122 non-null    int64
#  5   Region             122 non-null    int64
#  6   Continent          122 non-null    int64
#  7   Total Deaths       122 non-null    int64
# dtypes: int64(8)
# memory usage: 8.6 KB

# %%
print(final_df_grouped)
# Out:
#             Disaster Subgroup  Disaster Type  Disaster Subtype  Country  ISO  \
# Start Year
# 1900                        7              7                 6        7    7
# 1901                        2              2                 1        2    2
# 1902                       10             10                10       10   10
# 1903                       12             12                10       12   12
# 1904                        4              4                 4        4    4
# ...                       ...            ...               ...      ...  ...
# 2017                      371            371               282      371  371
# 2018                      336            336               241      336  336
# 2019                      438            438               282      438  438
# 2020                      403            403               254      403  403
# 2021                      317            317               185      317  317
#
# ...

# %%
final_df_grouped = final_df_grouped[["Disaster Type"]]
print(final_df_grouped)
# Out:
#             Disaster Type
# Start Year
# 1900                    7
# 1901                    2
# 1902                   10
# 1903                   12
# 1904                    4
# ...                   ...
# 2017                  371
# 2018                  336
# 2019                  438
# 2020                  403
# 2021                  317
#
# [122 rows x 1 columns]

# %%
final_df_grouped = final_df_grouped.reset_index()
print(final_df_grouped)
#final_df_grouped.head()
# Out:
#      Start Year  Disaster Type
# 0          1900              7
# 1          1901              2
# 2          1902             10
# 3          1903             12
# 4          1904              4
# ..          ...            ...
# 117        2017            371
# 118        2018            336
# 119        2019            438
# 120        2020            403
# 121        2021            317
#
# [122 rows x 2 columns]

# %%
final_df_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Start Year     122 non-null    int64
#  1   Disaster Type  122 non-null    int64
# dtypes: int64(2)
# memory usage: 2.0 KB

# %%
final_df_grouped["Start Year"] = pd.to_datetime(final_df_grouped["Start Year"])

# Set date column as index
final_df_grouped.set_index("Start Year", inplace=True)

# Inspect data 
#print(final_df_grouped.info())
print (final_df_grouped.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\Desktop\mentoring\DISASTERS\.venv\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Start Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[119], line 1
# ...

# %%
# Plot data
final_df_grouped.plot()
plt.xticks(,final_df_grouped.index)
plt.xlabel('Year')
plt.ylabel('Number of Natural Disasters')
plt.title('Natural Disasters Across Time')

plt.legend(["No. of disasters"])

plt.show()

#dodac horizontal index (rok)
#zmienic nazwe kolumny na Numbers of Disasters albo Frequency
#dodać tytuł plot tlt.
#zrobić coś podobnego, ale dodając kolumnę Continents (i może groupby na kontynent)

# %% [markdown]
# Dlaczego tutaj widać spadek a w Histplotcie pokazany jest duży wzrost w 2020?

# %%
#year 2020

year_2020 = pd.date_range(start="2020", end="2020", freq="M")
print (year_2020)
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='M')

# %%
for event_type in final_df_grouped['Disaster Type']:
    event_data = final_df_grouped[final_df_grouped['Disaster Type'] == event_type]
    plt.plot(event_data['Start Year'], event_data['EventCount'], label=event_type)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\Desktop\mentoring\DISASTERS\.venv\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Start Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[109], line 3
# ...

# %%
plt.plot(final_df_grouped['Disaster Type'], linestyle='--', marker='o', color = final_df_grouped['Continent'])

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Number of Events')
plt.title('Number of Events Over Years')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\Desktop\mentoring\DISASTERS\.venv\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Continent'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ...

# %%
# Group by Start Year and Continent, count the number of disasters
lineplot_df = final_df.groupby(['Start Year', 'Continent']).size().reset_index(name='Number of Disasters')

# Pivot the DataFrame to have continents as separate columns
pivot_df = lineplot_df.pivot(index='Start Year', columns='Continent', values='Number of Disasters')

# Plot the lines for each continent
plt.figure(figsize=(12, 6))
for continent in pivot_df.columns:
    plt.plot(pivot_df.index, pivot_df[continent], label=continent, marker = "o")

# labels and title
plt.xlabel('Year')
plt.ylabel('Number of Natural Disasters')
plt.title('Natural Disasters Across Time by Continent')


plt.legend()
plt.show()

# %% [markdown]
# # Notatki
